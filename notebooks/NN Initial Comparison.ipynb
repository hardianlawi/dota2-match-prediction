# %%
import os
import sys
sys.path.append('../')

import random as rn
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.metrics import accuracy_score, log_loss
from sklearn.model_selection import KFold

import tensorflow as tf

from src.utils.models import define_model, train_and_pred
from src.utils.data import load_data

pd.options.display.max_columns = 100
# %matplotlib inline
plt.style.use('seaborn')
# Out:
# /home/hardian_lawi/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
# The below is necessary in Python 3.2.3 onwards to
# have reproducible behavior for certain hash-based operations.
# See these references for further details:
# https://docs.python.org/3.4/using/cmdline.html#envvar-PYTHONHASHSEED
# https://github.com/fchollet/keras/issues/2280#issuecomment-306959926

def init_seeds(seed):

    os.environ['PYTHONHASHSEED'] = '0'

    # The below is necessary for starting Numpy generated random numbers
    # in a well-defined initial state.

    np.random.seed(seed)

    # The below is necessary for starting core Python generated random numbers
    # in a well-defined state.

    rn.seed(seed)

    # Force TensorFlow to use single thread.
    # Multiple threads are a potential source of
    # non-reproducible results.
    # For further details, see: https://stackoverflow.com/questions/42022950/which-seeds-have-to-be-set-where-to-realize-100-reproducibility-of-training-res

    session_conf = tf.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)

    from keras import backend as K

    # The below tf.set_random_seed() will make random number generation
    # in the TensorFlow backend have a well-defined initial state.
    # For further details, see: https://www.tensorflow.org/api_docs/python/tf/set_random_seed

    tf.set_random_seed(seed)

    sess = tf.Session(graph=tf.get_default_graph(), config=session_conf)
    
    K.set_session(sess)
    
    return sess

try:
    del sess
except:
    print('creating new session.')
    sess = init_seeds(0)
# Out:
# creating new session.
# Using TensorFlow backend.

# %%
radiant_cols = ['hero_' + str(i) for i in range(5)]
dire_cols = ['hero_' + str(i) for i in range(5, 10)]
no_heroes = 116

radiants, dires, df = load_data()

# %%
n_splits = 5
kf = KFold(n_splits, shuffle=True, random_state=10)

print('=================================================')

avg_score = {}
scores = {}
avg_threshold = 0

histories = {}

for i, (train_idx, test_idx) in enumerate(kf.split(df)):
    
    X_train = [radiants.iloc[train_idx].copy(), dires.iloc[train_idx].copy()]
    X_test = [radiants.iloc[test_idx].copy(), dires.iloc[test_idx].copy()]

    y_train = df.radiant_win.iloc[train_idx].values
    y_test = df.radiant_win.iloc[test_idx].values
    
    print('Iter', i)
    print('Train pos pctg', y_train.mean())
    print('Test pos pctg', y_test.mean())
    print('-------------------------------------------------\n')
    
    models_dict = {
        'custom_nn_relu': [
            define_model(activation='relu', name='custom_nn', optimizer='adam', seed=0),
        ],
        'custom_nn_tanh': [
            define_model(activation='tanh', name='custom_nn', optimizer='adam', seed=0),
        ],
        'custom_nn_l2_regularizer': [
            define_model(activation='relu', name='custom_nn_l2_regularizer', optimizer='adam', seed=0),
        ],
        'custom_nn_dropout': [
            define_model(activation='relu', name='custom_nn_dropout', optimizer='adam', seed=0),
        ],
        'nn_tanh': [
            define_model(activation='tanh', name='nn_tanh', optimizer='adam', seed=0),
        ],
        'nn_relu': [
            define_model(activation='relu', name='nn_relu', optimizer='adam', seed=0),
        ],
        'nn_l2_regularizer': [
            define_model(activation='relu', name='nn_l2_regularizer', optimizer='adam', seed=0),
        ],
        'nn_dropout': [
            define_model(activation='relu', name='nn_dropout', optimizer='adam', seed=0),
        ],
    }
    
    if i not in histories:
        histories[i] = {}
        
    scores[i] = {}
    
    for key, models in models_dict.items():
        
        if key not in avg_score:
            avg_score[key] = dict(train=0, test=0)
            
        if key not in histories[i]:
            histories[i][key] = {}
            
        temp_preds = train_and_pred(models, X_train, y_train, X_test, y_test, key)
        temp_scores = accuracy_score(y_train, temp_preds[0] > 0.5), \
            accuracy_score(y_test, temp_preds[1] > 0.5)
        
        avg_score[key]['train'] += temp_scores[0]
        avg_score[key]['test'] += temp_scores[1]
        
        scores[i][key] = temp_scores[1]

        print(key, '==', 
              'train: %.4f' % temp_scores[0], '-',
              'test: %.4f' % temp_scores[1])
        
        histories[i][key].update(temp_preds[2].history)

    print('=================================================\n')
          
############################################################################

print('Average score\n--------------------')
for key, models in models_dict.items():
    print(key, '=======', 
          'train:', avg_score[key]['train'] / n_splits, '----',
          'test:', avg_score[key]['test'] / n_splits)
# Out:
# =================================================
# Iter 0
# Train pos pctg 0.5376726663876099
# Test pos pctg 0.5424863959815822
# -------------------------------------------------
#
# WARNING:tensorflow:From /home/hardian_lawi/anaconda3/lib/python3.6/site-packages/tensorflow/python/ops/resource_variable_ops.py:432: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# custom_nn_relu == train: 0.5981 - test: 0.5629
# custom_nn_tanh == train: 0.5973 - test: 0.5719
# custom_nn_l2_regularizer == train: 0.5711 - test: 0.5675
# custom_nn_dropout == train: 0.6015 - test: 0.5676
# nn_tanh == train: 0.6599 - test: 0.5384
# nn_relu == train: 0.6433 - test: 0.5569
# nn_l2_regularizer == train: 0.5726 - test: 0.5714
# nn_dropout == train: 0.5946 - test: 0.5652
# =================================================
#
# Iter 1
# Train pos pctg 0.5393121250174411
# Test pos pctg 0.5359285614622575
# -------------------------------------------------
#
# custom_nn_relu == train: 0.6033 - test: 0.5663
# custom_nn_tanh == train: 0.5977 - test: 0.5616
# custom_nn_l2_regularizer == train: 0.5701 - test: 0.5666
# custom_nn_dropout == train: 0.5986 - test: 0.5743
# nn_tanh == train: 0.6587 - test: 0.5486
# nn_relu == train: 0.6479 - test: 0.5622
# nn_l2_regularizer == train: 0.5709 - test: 0.5595
# nn_dropout == train: 0.5941 - test: 0.5686
# =================================================
#
# Iter 2
# Train pos pctg 0.5378121947816381
# Test pos pctg 0.5419282824054695
# -------------------------------------------------
#
# custom_nn_relu == train: 0.6034 - test: 0.5719
# custom_nn_tanh == train: 0.5989 - test: 0.5647
# custom_nn_l2_regularizer == train: 0.5738 - test: 0.5677
# custom_nn_dropout == train: 0.6017 - test: 0.5739
# nn_tanh == train: 0.6561 - test: 0.5430
# nn_relu == train: 0.6436 - test: 0.5610
# nn_l2_regularizer == train: 0.5698 - test: 0.5650
# nn_dropout == train: 0.5882 - test: 0.5665
# =================================================
#
# Iter 3
# Train pos pctg 0.5390679503278917
# Test pos pctg 0.5369052602204548
# -------------------------------------------------
#
# custom_nn_relu == train: 0.6023 - test: 0.5647
# custom_nn_tanh == train: 0.6009 - test: 0.5581
# custom_nn_l2_regularizer == train: 0.5726 - test: 0.5670
# custom_nn_dropout == train: 0.6043 - test: 0.5652
# nn_tanh == train: 0.6588 - test: 0.5411
# nn_relu == train: 0.6456 - test: 0.5541
# nn_l2_regularizer == train: 0.5758 - test: 0.5605
# nn_dropout == train: 0.5879 - test: 0.5587
# =================================================
#
# Iter 4
# Train pos pctg 0.5393121250174411
# Test pos pctg 0.5359285614622575
# -------------------------------------------------
#
# custom_nn_relu == train: 0.6004 - test: 0.5768
# custom_nn_tanh == train: 0.6009 - test: 0.5696
# custom_nn_l2_regularizer == train: 0.5693 - test: 0.5705
# custom_nn_dropout == train: 0.5975 - test: 0.5684
# nn_tanh == train: 0.6551 - test: 0.5429
# nn_relu == train: 0.6497 - test: 0.5478
# nn_l2_regularizer == train: 0.5702 - test: 0.5633
# nn_dropout == train: 0.5912 - test: 0.5668
# =================================================
#
# Average score
# --------------------
# custom_nn_relu ======= train: 0.6015069066555043 ---- test: 0.5685223943072415
# custom_nn_tanh ======= train: 0.5991279475373238 ---- test: 0.5651737128505652
# custom_nn_l2_regularizer ======= train: 0.5714036556439235 ---- test: 0.5678805636947118
# custom_nn_dropout ======= train: 0.6007255476489466 ---- test: 0.5698897725687178
# nn_tanh ======= train: 0.6577228966094599 ---- test: 0.5428212641272498
# nn_relu ======= train: 0.6460164643504952 ---- test: 0.5563834240267894
# nn_l2_regularizer ======= train: 0.5718501465048138 ---- test: 0.5639179573043114
# nn_dropout ======= train: 0.5911887819171201 ---- test: 0.5651458071717594

# %%
reform = {(metric, fold, model): values 
          for fold, interDict in histories.items() 
          for model, innerDict in interDict.items()
          for metric, values in innerDict.items()}

reform = pd.DataFrame(reform)

reform['val_loss'][0].plot(figsize=(12, 6))
plt.xlabel('epoch', fontsize=12)
plt.ylabel('Validation Log loss', fontsize=12)
# Out:
# Text(0, 0.5, 'Validation Log loss')
