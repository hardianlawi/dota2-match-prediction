# %%
import sys
sys.path.append('../')

import json
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from src.database import MongoDB

from sklearn.preprocessing import OneHotEncoder

pd.options.display.max_columns = 100

# %matplotlib inline

# %%
def hotencode(df):
    unq, idx = np.unique(df, return_inverse=1)
    col_idx = idx.reshape(df.shape)
    out = np.zeros((len(col_idx),col_idx.max()+1),dtype=int)
    out[np.arange(len(col_idx))[:,None], col_idx] = 1
    return pd.DataFrame(out, columns=unq, index=df.index)

# %%
radiant_cols = ['hero_' + str(i) for i in range(5)]
dire_cols = ['hero_' + str(i) for i in range(5, 10)]
hero_cols = ['hero_' + str(i) for i in range(10)]

# %% [markdown]
# ## Overview

# %%
df = pd.read_csv('../data/matches_data.csv')
df.shape
# Out:
# (38357, 12)

# %%
df.head()
# Out:
#      match_id  hero_0  hero_1  hero_2  hero_3  hero_4  hero_5  hero_6  hero_7  \
# 0  4154000815      83      64      93      99      22     110      32      41
# 1  4152678603      17      26      99      48       9      70      27       2
# 2  4152494309      23     120      82      18      26     108      31       7
# 3  4152425012     121      18     106      21      86      10      82     112
# 4  4152417604      77      93      45      26       7     119      14       4
#
#    hero_8  hero_9  radiant_win
# 0      92      11        False
# 1       1      75         True
# 2      14      44        False
# 3     110      14        False
# 4     106      70        False

# %% [markdown]
# ### Any null values?

# %%
df.isnull().sum()
# Out:
# match_id       0
# hero_0         0
# hero_1         0
# hero_2         0
# hero_3         0
# hero_4         0
# hero_5         0
# hero_6         0
# hero_7         0
# hero_8         0
# hero_9         0
# radiant_win    0
# dtype: int64

# %% [markdown]
# ### Percentage of radiants winning

# %%
df.radiant_win.mean()
# Out:
# 0.5379982793232004

# %% [markdown]
# It's almost about 50 50, so doesn't seem like there is any major difference in terms of team played.

# %% [markdown]
# ### Are all heroes used in the data matches?

# %%
radiants = df[radiant_cols]
print('Number of unique heroes used in radiants:', len(set(radiants.values.ravel())))

dires = df[dire_cols]
print('Number of unique heroes used in dires:', len(set(dires.values.ravel())))
# Out:
# Number of unique heroes used in radiants: 116
# Number of unique heroes used in dires: 116

# %% [markdown]
# Apparently, all heroes have been used in as both radiants and dires.

# %% [markdown]
# ### Check if there are any matches with the same sets of heroes that have different outcomes.

# %%
df['radiants_team'] = list(map(sorted, df[radiant_cols].values.tolist()))
df['radiants_team'] = df['radiants_team'].map(lambda x: ', '.join(map(str, x)))

df['dires_team'] = list(map(sorted, df[dire_cols].values.tolist()))
df['dires_team'] = df['dires_team'].map(lambda x: ', '.join(map(str, x)))

# %%
df.drop_duplicates(subset=['radiants_team', 'dires_team']).shape
# Out:
# (38357, 14)

# %% [markdown]
# Since after dropping duplicates based on `radiants_team` and `dires_team`, we still get the original shape of the df which means that all the matches have different combinations of heroes in both radiants and dires.

# %% [markdown]
# # Hero

# %%
with open('../data/hero_stats.json', 'r') as f:
    heroes_stats = json.load(f)
    heroes_stats = pd.DataFrame(heroes_stats).set_index('id')
    
with open('../data/hero_data.json', 'r') as f:
    heroes_data = json.load(f)
    heroes_data = pd.DataFrame(heroes_data).set_index('id')
    
assert len(heroes_stats) == len(heroes_data)

no_heroes = len(heroes_stats)

heroes = heroes_stats.merge(heroes_data, left_index=True, right_index=True)
heroes.head()
# Out:
#     1_pick  1_win  2_pick  2_win  3_pick  3_win  4_pick  4_win  5_pick  5_win  \
# id
# 1     3819   1861   17546   8841   38115  19515   54088  28335   38746  20537
# 2     6126   3331   26952  14620   51597  27905   68232  36490   48797  25890
# 3      712    337    2982   1324    6645   2902   10286   4727    9229   4308
# 4     6735   3505   24397  12680   41077  21296   50922  26689   35503  18452
# 5     4001   2191   18742  10161   39066  21039   58829  31605   48403  25501
#
#     6_pick  6_win  7_pick  7_win  8_pick  8_win  agi_gain  attack_range  \
# id
# 1    10384   5525    1565    824     149     83       2.8           150
# 2    14492   7616    2839   1425     339    166       2.2           150
# 3     3691   1819    1186    577     319    174       2.4           400
# 4    12009   6279    2948   1555     514    276       3.0           150
# 5    17035   8948    3931   2096     675    368       1.6           600
#
#     attack_rate attack_type_x  base_agi  base_armor  base_attack_max  \
# id
# 1           1.4         Melee        22        -1.0               33
# 2           1.7         Melee        20        -2.0               28
# 3           1.7        Ranged        23         1.0               41
# 4           1.7         Melee        24         0.0               39
# 5           1.7        Ranged        16         0.0               32
#
#     base_attack_min  base_health  base_health_regen  base_int  base_mana  \
# id
# 1                29          200               1.75        12         75
# 2                24          200               4.25        18         75
# 3                35          200               1.50        23         75
# 4                33          200               1.50        18         75
# 5                26          200               1.50        14         75
#
#     base_mana_regen  base_mr  base_str  cm_enabled  hero_id  \
# id
# 1               0.9       25        23        True      1.0
# 2               0.9       25        25        True      2.0
# 3               0.9       25        23        True      3.0
# 4               0.9       25        24        True      4.0
# 5               0.9       25        18        True      5.0
#
#                                                  icon  \
# id
# 1         /apps/dota2/images/heroes/antimage_icon.png
# 2              /apps/dota2/images/heroes/axe_icon.png
# 3             /apps/dota2/images/heroes/bane_icon.png
# 4      /apps/dota2/images/heroes/bloodseeker_icon.png
# 5   /apps/dota2/images/heroes/crystal_maiden_icon.png
#
#                                                   img  int_gain  legs_x  \
# id
# 1        /apps/dota2/images/heroes/antimage_full.png?       1.8       2
# 2             /apps/dota2/images/heroes/axe_full.png?       1.6       2
# 3            /apps/dota2/images/heroes/bane_full.png?       2.4       4
# 4     /apps/dota2/images/heroes/bloodseeker_full.png?       1.7       2
# 5   /apps/dota2/images/heroes/crystal_maiden_full....       2.9       2
#
#    localized_name_x  move_speed                        name_x primary_attr_x  \
# id
# 1         Anti-Mage         310        npc_dota_hero_antimage            agi
# 2               Axe         290             npc_dota_hero_axe            str
# 3              Bane         310            npc_dota_hero_bane            int
# 4       Bloodseeker         285     npc_dota_hero_bloodseeker            agi
# 5    Crystal Maiden         275  npc_dota_hero_crystal_maiden            int
#
#     pro_ban  pro_pick  pro_win  projectile_speed  \
# id
# 1      20.0      17.0     10.0                 0
# 2      43.0      57.0     33.0               900
# 3      48.0      87.0     44.0               900
# 4      89.0      53.0     26.0               900
# 5       5.0      67.0     41.0               900
#
#                                          roles_x  str_gain  turn_rate  \
# id
# 1                         [Carry, Escape, Nuker]       1.3        0.5
# 2        [Initiator, Durable, Disabler, Jungler]       2.8        0.6
# 3            [Support, Disabler, Nuker, Durable]       2.4        0.6
# 4   [Carry, Disabler, Jungler, Nuker, Initiator]       2.7        0.5
# 5            [Support, Disabler, Nuker, Jungler]       2.0        0.5
#
#    attack_type_y  legs_y localized_name_y                        name_y  \
# id
# 1          Melee       2        Anti-Mage        npc_dota_hero_antimage
# 2          Melee       2              Axe             npc_dota_hero_axe
# 3         Ranged       4             Bane            npc_dota_hero_bane
# 4          Melee       2      Bloodseeker     npc_dota_hero_bloodseeker
# 5         Ranged       2   Crystal Maiden  npc_dota_hero_crystal_maiden
#
#    primary_attr_y                                       roles_y
# id
# 1             agi                        [Carry, Escape, Nuker]
# 2             str       [Initiator, Durable, Disabler, Jungler]
# 3             int           [Support, Disabler, Nuker, Durable]
# 4             agi  [Carry, Disabler, Jungler, Nuker, Initiator]
# 5             int           [Support, Disabler, Nuker, Jungler]
